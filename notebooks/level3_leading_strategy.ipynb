# %% [markdown]
# # Level3 AI Leading Card Strategies

# %% [markdown]
# This notebook demonstrates how the Level3 AI chooses which card to lead.

# %% [markdown]
# ## Setup and Imports

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))
print('✅ Imports successful')
