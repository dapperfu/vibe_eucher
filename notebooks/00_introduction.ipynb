# %% [markdown]
# # PyTorch AI Player Statistical Analysis
#
# This notebook series provides comprehensive statistical analysis of PyTorch AI players in Euchre.
#
# ## Notebook Organization
#
# - **0x_***: Introduction and data manipulation
# - **1x_***: Statistical analysis
# - **2x_***: Visualization and plotting
#
# ## Setup
#
# First, let's set up the environment and import necessary libraries.

# %%
import sys
from pathlib import Path

# Add project root to path
project_root = Path().resolve().parent
sys.path.insert(0, str(project_root))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import json
from datetime import datetime
from collections import Counter

# Set plotting style
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

print(f"Project root: {project_root}")
print(f"Python version: {sys.version}")
print(f"NumPy version: {np.__version__}")
print(f"Pandas version: {pd.__version__}")

# %% [markdown]
# ## Directory Structure
#
# Check that required directories exist:

# %%
# Check directories
dirs_to_check = ["stats", "logs", "models", "training_data"]
for dir_name in dirs_to_check:
    dir_path = project_root / dir_name
    exists = dir_path.exists()
    print(f"{dir_name}: {'✓' if exists else '✗'} {dir_path}")
