# %% [markdown]
# # M-Series AI Decision Making Demonstration

# %%
import sys
from pathlib import Path
print("Python version:", sys.version)
print("Current directory:", Path.cwd())
# Out:
# Python version: 3.12.3 (main, Jun 18 2025, 17:59:45) [GCC 13.3.0]
# Current directory: /projects/vibe_eucher/notebooks

# %%
try:
    from euchre.models import Card, Suit, Rank
    print("Core euchre models imported successfully")
except ImportError as e:
    print(f"Import error: {e}")
# Out:
# Core euchre models imported successfully

# %%
try:
    from euchre.core.deck import Deck
    deck = Deck()
    print(f"Deck size: {deck.size} cards")
    print("Deck created successfully")
except ImportError as e:
    print(f"Import error: {e}")
# Out:
# Deck size: 24 cards
# Deck created successfully

# %%
try:
    from euchre.models import Card, Suit, Rank
    hand = [Card(Rank.ACE, Suit.HEARTS), Card(Rank.KING, Suit.HEARTS)]
    print(f"Hand created: {[str(card) for card in hand]}")
except ImportError as e:
    print(f"Import error: {e}")
# Out:
# Hand created: ['Ace of Hearts', 'King of Hearts']
