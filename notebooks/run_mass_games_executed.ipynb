# %% [markdown]
# # Mass Euchre Game Runner
#
# This notebook provides tools to run large numbers of euchre games for:
# - Training data generation
# - AI performance evaluation
# - Strategy analysis
# - Statistical analysis

# %% [markdown]
# ## Setup and Imports

# %%
import sys
import os
import json
from pathlib import Path

# Add the parent directory to the path to import euchre modules
sys.path.append(str(Path.cwd().parent))

from euchre.mass_game_runner import MassGameRunner
from euchre.ai_profiles import AggressiveAI, ConservativeAI, BalancedAI, OpportunisticAI
from euchre.models import PlayerType
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm

print("✅ Imports successful")
# Out:
# ✅ Imports successful

# %% [markdown]
# ## Initialize Mass Game Runner

# %%
# Initialize the mass game runner
runner = MassGameRunner()

print("🚀 Mass Game Runner initialized")
# Out:
# 🚀 Mass Game Runner initialized

# %% [markdown]
# ## View Available Team Configurations

# %%
# The MassGameRunner has predefined team configurations
print("📋 Available team configurations:")
for config_name in runner.team_configs.keys():
    config = runner.team_configs[config_name]
    team1_players = config['team1']
    team2_players = config['team2']
    print(f"  {config_name}: {len(team1_players)} vs {len(team2_players)} players")
    print(f"    Team1: {[f'{p[0]} ({p[1]}, risk={p[2]})' for p in team1_players]}")
    print(f"    Team2: {[f'{p[0]} ({p[1]}, risk={p[2]})' for p in team2_players]}")
# Out:
# 📋 Available team configurations:
#   aggressive_vs_conservative: 2 vs 2 players
#     Team1: ['Alice (aggressive, risk=0.8)', 'Bob (aggressive, risk=0.8)']
#     Team2: ['Charlie (conservative, risk=0.2)', 'David (conservative, risk=0.2)']
#   aggressive_vs_balanced: 2 vs 2 players
#     Team1: ['Alice (aggressive, risk=0.8)', 'Bob (aggressive, risk=0.8)']
#     Team2: ['Charlie (balanced, risk=0.5)', 'David (balanced, risk=0.5)']
#   conservative_vs_balanced: 2 vs 2 players
#     Team1: ['Alice (conservative, risk=0.2)', 'Bob (conservative, risk=0.2)']
#     Team2: ['Charlie (balanced, risk=0.5)', 'David (balanced, risk=0.5)']
#   opportunistic_vs_aggressive: 2 vs 2 players
#     Team1: ['Alice (opportunistic, risk=0.7)', 'Bob (opportunistic, risk=0.7)']
#     Team2: ['Charlie (aggressive, risk=0.8)', 'David (aggressive, risk=0.8)']
#   mixed_vs_mixed: 2 vs 2 players
#     Team1: ['Alice (aggressive, risk=0.8)', 'Bob (conservative, risk=0.2)']
#     Team2: ['Charlie (balanced, risk=0.5)', 'David (opportunistic, risk=0.7)']

# %% [markdown]
# ## Run Mass Games

# %%
# Run games for each configuration
games_per_config = 100  # Adjust as needed
config_names = list(runner.team_configs.keys())
total_games = len(config_names) * games_per_config

print(f"🎮 Running {total_games} total games...")
print(f"📊 {games_per_config} games per configuration")
print(f"🎯 Configurations: {config_names}")

# Run games for each configuration
for config_name in config_names:
    print(f"\n🎯 Running {config_name}...")
    
    # Run games for this configuration using the correct API
    runner.run_games(games_per_config, config_name)
    
    print(f"  ✅ Completed {games_per_config} games for {config_name}")

print("\n✅ All games completed!")
print(f"📁 Results saved to: {runner.output_dir}")
# Out:
# 🎮 Running 500 total games...
# 📊 100 games per configuration
# 🎯 Configurations: ['aggressive_vs_conservative', 'aggressive_vs_balanced', 'conservative_vs_balanced', 'opportunistic_vs_aggressive', 'mixed_vs_mixed']
#
# 🎯 Running aggressive_vs_conservative...
# Starting 100 games with configuration: aggressive_vs_conservative
# Team 1: ['Alice (aggressive, risk=0.8)', 'Bob (aggressive, risk=0.8)']
# Team 2: ['Charlie (conservative, risk=0.2)', 'David (conservative, risk=0.2)']
# Using 16 parallel workers
# --------------------------------------------------------------------------------
# Game 1/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 2/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 3/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 4/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 5/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 6/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 7/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 8/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 9/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 10/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 11/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 12/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 13/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 14/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 15/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 16/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 17/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 18/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 19/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 20/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 21/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 22/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 23/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 24/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 25/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 26/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 27/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 28/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 29/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 30/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 31/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 32/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 33/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 34/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 35/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 36/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 37/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 38/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 39/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 40/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 41/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 42/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 43/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 44/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 45/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 46/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 47/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 48/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 49/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 50/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 51/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 52/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 53/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 54/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 55/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 56/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 57/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 58/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 59/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 60/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 61/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 62/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 63/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 64/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 65/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 66/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 67/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 68/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 69/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 70/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 71/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 72/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 73/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 74/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 75/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 76/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 77/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 78/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 79/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 80/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 81/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 82/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 83/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 84/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 85/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 86/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 87/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 88/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 89/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 90/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 91/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 92/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 93/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 94/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 95/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 96/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 97/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 98/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 99/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 100/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Progress: 100/100 games completed (0 successful, 100 failed)
# --------------------------------------------------------------------------------
# Completed 100 games!
# Successful: 0
# Failed: 100
# Results saved to: games
#   ✅ Completed 100 games for aggressive_vs_conservative
#
# 🎯 Running aggressive_vs_balanced...
# Starting 100 games with configuration: aggressive_vs_balanced
# Team 1: ['Alice (aggressive, risk=0.8)', 'Bob (aggressive, risk=0.8)']
# Team 2: ['Charlie (balanced, risk=0.5)', 'David (balanced, risk=0.5)']
# Using 16 parallel workers
# --------------------------------------------------------------------------------
# Game 1/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 2/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 3/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 4/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 5/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 6/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 7/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 8/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 9/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 10/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 11/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 12/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 13/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 14/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 15/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 16/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 17/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 18/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 19/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 20/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 21/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 22/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 23/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 24/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 25/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 26/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 27/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 28/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 29/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 30/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 31/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 32/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 33/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 34/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 35/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 36/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 37/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 38/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 39/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 40/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 41/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 42/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 43/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 44/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 45/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 46/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 47/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 48/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 49/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 50/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 51/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 52/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 53/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 54/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 55/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 56/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 57/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 58/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 59/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 60/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 61/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 62/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 63/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 64/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 65/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 66/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 67/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 68/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 69/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 70/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 71/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 72/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 73/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 74/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 75/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 76/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 77/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 78/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 79/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 80/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 81/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 82/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 83/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 84/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 85/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 86/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 87/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 88/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 89/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 90/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 91/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 92/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 93/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 94/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 95/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 96/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 97/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 98/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 99/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 100/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Progress: 100/100 games completed (0 successful, 100 failed)
# --------------------------------------------------------------------------------
# Completed 100 games!
# Successful: 0
# Failed: 100
# Results saved to: games
#   ✅ Completed 100 games for aggressive_vs_balanced
#
# 🎯 Running conservative_vs_balanced...
# Starting 100 games with configuration: conservative_vs_balanced
# Team 1: ['Alice (conservative, risk=0.2)', 'Bob (conservative, risk=0.2)']
# Team 2: ['Charlie (balanced, risk=0.5)', 'David (balanced, risk=0.5)']
# Using 16 parallel workers
# --------------------------------------------------------------------------------
# Game 1/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 2/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 3/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 4/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 5/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 6/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 7/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 8/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 9/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 10/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 11/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 12/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 13/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 14/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 15/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 16/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 17/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 18/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 19/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 20/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 21/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 22/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 23/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 24/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 25/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 26/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 27/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 28/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 29/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 30/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 31/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 32/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 33/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 34/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 35/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 36/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 37/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 38/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 39/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 40/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 41/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 42/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 43/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 44/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 45/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 46/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 47/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 48/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 49/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 50/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 51/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 52/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 53/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 54/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 55/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 56/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 57/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 58/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 59/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 60/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 61/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 62/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 63/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 64/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 65/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 66/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 67/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 68/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 69/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 70/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 71/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 72/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 73/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 74/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 75/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 76/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 77/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 78/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 79/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 80/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 81/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 82/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 83/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 84/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 85/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 86/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 87/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 88/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 89/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 90/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 91/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 92/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 93/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 94/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 95/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 96/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 97/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 98/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 99/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 100/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Progress: 100/100 games completed (0 successful, 100 failed)
# --------------------------------------------------------------------------------
# Completed 100 games!
# Successful: 0
# Failed: 100
# Results saved to: games
#   ✅ Completed 100 games for conservative_vs_balanced
#
# 🎯 Running opportunistic_vs_aggressive...
# Starting 100 games with configuration: opportunistic_vs_aggressive
# Team 1: ['Alice (opportunistic, risk=0.7)', 'Bob (opportunistic, risk=0.7)']
# Team 2: ['Charlie (aggressive, risk=0.8)', 'David (aggressive, risk=0.8)']
# Using 16 parallel workers
# --------------------------------------------------------------------------------
# Game 1/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 2/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 3/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 4/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 5/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 6/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 7/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 8/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 9/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 10/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 11/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 12/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 13/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 14/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 15/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 16/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 17/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 18/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 19/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 20/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 21/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 22/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 23/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 24/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 25/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 26/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 27/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 28/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 29/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 30/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 31/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 32/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 33/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 34/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 35/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 36/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 37/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 38/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 39/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 40/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 41/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 42/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 43/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 44/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 45/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 46/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 47/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 48/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 49/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 50/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 51/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 52/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 53/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 54/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 55/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 56/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 57/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 58/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 59/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 60/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 61/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 62/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 63/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 64/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 65/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 66/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 67/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 68/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 69/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 70/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 71/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 72/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 73/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 74/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 75/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 76/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 77/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 78/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 79/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 80/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 81/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 82/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 83/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 84/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 85/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 86/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 87/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 88/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 89/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 90/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 91/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 92/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 93/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 94/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 95/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 96/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 97/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 98/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 99/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 100/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Progress: 100/100 games completed (0 successful, 100 failed)
# --------------------------------------------------------------------------------
# Completed 100 games!
# Successful: 0
# Failed: 100
# Results saved to: games
#   ✅ Completed 100 games for opportunistic_vs_aggressive
#
# 🎯 Running mixed_vs_mixed...
# Starting 100 games with configuration: mixed_vs_mixed
# Team 1: ['Alice (aggressive, risk=0.8)', 'Bob (conservative, risk=0.2)']
# Team 2: ['Charlie (balanced, risk=0.5)', 'David (opportunistic, risk=0.7)']
# Using 16 parallel workers
# --------------------------------------------------------------------------------
# Game 1/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 2/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 3/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 4/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 5/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 6/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 7/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 8/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 9/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 10/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 11/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 12/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 13/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 14/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 15/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 16/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 17/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 18/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 19/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 20/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 21/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 22/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 23/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 24/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 25/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 26/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 27/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 28/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 29/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 30/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 31/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 32/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 33/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 34/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 35/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 36/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 37/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 38/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 39/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 40/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 41/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 42/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 43/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 44/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 45/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 46/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 47/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 48/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 49/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 50/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 51/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 52/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 53/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 54/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 55/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 56/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 57/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 58/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 59/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 60/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 61/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 62/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 63/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 64/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 65/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 66/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 67/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 68/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 69/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 70/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 71/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 72/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 73/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 74/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 75/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 76/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 77/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 78/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 79/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 80/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 81/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 82/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 83/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 84/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 85/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 86/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 87/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 88/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 89/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 90/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 91/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 92/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 93/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 94/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 95/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 96/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 97/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 98/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 99/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 100/100: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Progress: 100/100 games completed (0 successful, 100 failed)
# --------------------------------------------------------------------------------
# Completed 100 games!
# Successful: 0
# Failed: 100
# Results saved to: games
#   ✅ Completed 100 games for mixed_vs_mixed
#
# ✅ All games completed!
# 📁 Results saved to: games

# %% [markdown]
# ## Load and Analyze Results

# %%
# Get all game result files
game_files = runner.get_game_files()
print(f"📊 Found {len(game_files)} game result files")

# Load results into a list
all_games = []
for game_file in game_files:
    try:
        with open(game_file, 'r') as f:
            game_data = json.load(f)
            if 'error' not in game_data:  # Skip failed games
                all_games.append(game_data)
    except Exception as e:
        print(f"⚠️  Error loading {game_file}: {e}")

print(f"✅ Successfully loaded {len(all_games)} completed games")
# Out:
# 📊 Found 1750 game result files
# ✅ Successfully loaded 1250 completed games

# %% [markdown]
# ## Convert to DataFrame

# %%
# Convert results to DataFrame for analysis
if all_games:
    # Extract key data for analysis
    analysis_data = []
    for game in all_games:
        analysis_data.append({
            'game_id': game['game_id'],
            'config': game['team_config'],
            'winner': game['winner'],
            'team1_score': game['team1']['final_score'],
            'team2_score': game['team2']['final_score'],
            'total_rounds': game['total_rounds'],
            'game_duration': game['game_duration']
        })
    
    df = pd.DataFrame(analysis_data)
    print(f"📊 Total games analyzed: {len(df)}")
    print(f"\n📋 Columns: {list(df.columns)}")
    df.head()
else:
    print("⚠️  No completed games found to analyze")
# Out:
# 📊 Total games analyzed: 1250
#
# 📋 Columns: ['game_id', 'config', 'winner', 'team1_score', 'team2_score', 'total_rounds', 'game_duration']

# %% [markdown]
# ## Statistical Analysis

# %%
if 'df' in locals() and len(df) > 0:
    # Overall statistics
    print("📊 OVERALL STATISTICS")
    print("=" * 50)
    
    # Win rates by configuration
    print("\n🏆 Win Rates by Configuration:")
    for config_name in df['config'].unique():
        config_df = df[df['config'] == config_name]
        team1_wins = len(config_df[config_df['winner'] == 'team1'])
        team2_wins = len(config_df[config_df['winner'] == 'team2'])
        ties = len(config_df[config_df['winner'] == 'tie'])
        total = len(config_df)
        
        print(f"  {config_name}:")
        print(f"    Team1: {team1_wins}/{total} ({team1_wins/total:.1%})")
        print(f"    Team2: {team2_wins}/{total} ({team2_wins/total:.1%})")
        if ties > 0:
            print(f"    Ties: {ties}/{total} ({ties/total:.1%})")
    
    # Game length statistics
    print(f"\n⏱️  Game Length Statistics:")
    print(f"  Average: {df['total_rounds'].mean():.1f} rounds")
    print(f"  Median: {df['total_rounds'].median():.1f} rounds")
    print(f"  Min: {df['total_rounds'].min()} rounds")
    print(f"  Max: {df['total_rounds'].max()} rounds")
    print(f"  Std Dev: {df['total_rounds'].std():.1f} rounds")
    
    # Score statistics
    print(f"\n📈 Score Statistics:")
    print(f"  Team1 Avg Score: {df['team1_score'].mean():.1f}")
    print(f"  Team2 Avg Score: {df['team2_score'].mean():.1f}")
    print(f"  Highest Score: {max(df['team1_score'].max(), df['team2_score'].max())}")
else:
    print("⚠️  No data available for analysis")
# Out:
# 📊 OVERALL STATISTICS
# ==================================================
#
# 🏆 Win Rates by Configuration:
#   aggressive_vs_balanced:
#     Team1: 126/250 (50.4%)
#     Team2: 124/250 (49.6%)
#   opportunistic_vs_aggressive:
#     Team1: 112/250 (44.8%)
#     Team2: 138/250 (55.2%)
#   aggressive_vs_conservative:
#     Team1: 125/250 (50.0%)
#     Team2: 125/250 (50.0%)
#   mixed_vs_mixed:
#     Team1: 119/250 (47.6%)
#     Team2: 131/250 (52.4%)
#   conservative_vs_balanced:
#     Team1: 121/250 (48.4%)
#     Team2: 129/250 (51.6%)
#
# ⏱️  Game Length Statistics:
#   Average: 16.4 rounds
#   Median: 17.0 rounds
#   Min: 10 rounds
#   Max: 19 rounds
#   Std Dev: 2.0 rounds
#
# 📈 Score Statistics:
#   Team1 Avg Score: 8.2
#   Team2 Avg Score: 8.3
#   Highest Score: 10

# %% [markdown]
# ## Visualizations

# %%
if 'df' in locals() and len(df) > 0:
    # Set up plotting style
    plt.style.use('seaborn-v0_8')
    sns.set_palette("husl")
    
    # Create subplots
    fig, axes = plt.subplots(2, 2, figsize=(15, 12))
    
    # 1. Win rates by configuration
    ax1 = axes[0, 0]
    config_names = df['config'].unique()
    team1_win_rates = []
    team2_win_rates = []
    
    for config_name in config_names:
        config_df = df[df['config'] == config_name]
        team1_wins = len(config_df[config_df['winner'] == 'team1'])
        team2_wins = len(config_df[config_df['winner'] == 'team2'])
        total = len(config_df)
        
        team1_win_rates.append(team1_wins / total)
        team2_win_rates.append(team2_wins / total)
    
    x = range(len(config_names))
    width = 0.35
    
    ax1.bar([i - width/2 for i in x], team1_win_rates, width, label='Team1', alpha=0.8)
    ax1.bar([i + width/2 for i in x], team2_win_rates, width, label='Team2', alpha=0.8)
    ax1.set_xlabel('Configuration')
    ax1.set_ylabel('Win Rate')
    ax1.set_title('Win Rates by Configuration')
    ax1.set_xticks(x)
    ax1.set_xticklabels(config_names, rotation=45)
    ax1.legend()
    ax1.grid(True, alpha=0.3)
    
    # 2. Game length distribution
    ax2 = axes[0, 1]
    ax2.hist(df['total_rounds'], bins=20, alpha=0.7, edgecolor='black')
    ax2.set_xlabel('Game Length (Rounds)')
    ax2.set_ylabel('Frequency')
    ax2.set_title('Game Length Distribution')
    ax2.grid(True, alpha=0.3)
    
    # 3. Win rates comparison
    ax3 = axes[1, 0]
    overall_team1_wins = len(df[df['winner'] == 'team1'])
    overall_team2_wins = len(df[df['winner'] == 'team2'])
    overall_ties = len(df[df['winner'] == 'tie'])
    total_games = len(df)
    
    labels = ['Team1 Wins', 'Team2 Wins']
    sizes = [overall_team1_wins, overall_team2_wins]
    colors = ['lightblue', 'lightcoral']
    
    if overall_ties > 0:
        labels.append('Ties')
        sizes.append(overall_ties)
        colors.append('lightgreen')
    
    ax3.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
    ax3.set_title('Overall Win Distribution')
    
    # 4. Score distributions
    ax4 = axes[1, 1]
    ax4.hist(df['team1_score'], bins=15, alpha=0.7, label='Team1 Scores', density=True)
    ax4.hist(df['team2_score'], bins=15, alpha=0.7, label='Team2 Scores', density=True)
    ax4.set_xlabel('Final Score')
    ax4.set_ylabel('Density')
    ax4.set_title('Score Distributions')
    ax4.legend()
    ax4.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()
else:
    print("⚠️  No data available for visualization")

# %% [markdown]
# ## Export Results

# %%
if 'df' in locals() and len(df) > 0:
    # Export results to CSV
    output_file = "mass_game_results.csv"
    df.to_csv(output_file, index=False)
    print(f"💾 Results exported to {output_file}")
    
    # Export summary statistics
    summary_stats = {
        'total_games': len(df),
        'team1_wins': len(df[df['winner'] == 'team1']),
        'team2_wins': len(df[df['winner'] == 'team2']),
        'ties': len(df[df['winner'] == 'tie']),
        'avg_game_length': df['total_rounds'].mean(),
        'avg_team1_score': df['team1_score'].mean(),
        'avg_team2_score': df['team2_score'].mean()
    }
    
    print("\n📊 Summary Statistics:")
    for key, value in summary_stats.items():
        if isinstance(value, float):
            print(f"  {key}: {value:.2f}")
        else:
            print(f"  {key}: {value}")
else:
    print("⚠️  No data available for export")
# Out:
# 💾 Results exported to mass_game_results.csv
#
# 📊 Summary Statistics:
#   total_games: 1250
#   team1_wins: 603
#   team2_wins: 647
#   ties: 0
#   avg_game_length: 16.44
#   avg_team1_score: 8.19
#   avg_team2_score: 8.26

# %% [markdown]
# ## Run All Configurations at Once

# %%
# Alternative: Run all configurations at once
print("🚀 Running all configurations at once...")
games_per_config = 50  # Adjust as needed

runner.run_all_configurations(games_per_config)

print("✅ All configurations completed!")
print(f"📁 Results saved to: {runner.output_dir}")
# Out:
# 🚀 Running all configurations at once...
# Running 50 games for each of 5 configurations
# ================================================================================
#
# Running configuration: aggressive_vs_conservative
# Starting 50 games with configuration: aggressive_vs_conservative
# Team 1: ['Alice (aggressive, risk=0.8)', 'Bob (aggressive, risk=0.8)']
# Team 2: ['Charlie (conservative, risk=0.2)', 'David (conservative, risk=0.2)']
# Using 16 parallel workers
# --------------------------------------------------------------------------------
# Game 1/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 2/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 3/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 4/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 5/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 6/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 7/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 8/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 9/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 10/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 11/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 12/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 13/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 14/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 15/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 16/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 17/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 18/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 19/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 20/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 21/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 22/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 23/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 24/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 25/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 26/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 27/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 28/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 29/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 30/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 31/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 32/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 33/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 34/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 35/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 36/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 37/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 38/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 39/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 40/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 41/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 42/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 43/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 44/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 45/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 46/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 47/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 48/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 49/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 50/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# --------------------------------------------------------------------------------
# Completed 50 games!
# Successful: 0
# Failed: 50
# Results saved to: games
# Completed configuration: aggressive_vs_conservative
# ================================================================================
#
# Running configuration: aggressive_vs_balanced
# Starting 50 games with configuration: aggressive_vs_balanced
# Team 1: ['Alice (aggressive, risk=0.8)', 'Bob (aggressive, risk=0.8)']
# Team 2: ['Charlie (balanced, risk=0.5)', 'David (balanced, risk=0.5)']
# Using 16 parallel workers
# --------------------------------------------------------------------------------
# Game 1/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 2/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 3/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 4/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 5/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 6/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 7/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 8/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 9/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 10/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 11/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 12/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 13/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 14/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 15/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 16/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 17/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 18/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 19/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 20/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 21/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 22/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 23/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 24/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 25/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 26/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 27/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 28/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 29/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 30/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 31/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 32/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 33/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 34/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 35/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 36/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 37/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 38/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 39/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 40/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 41/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 42/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 43/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 44/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 45/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 46/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 47/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 48/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 49/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 50/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# --------------------------------------------------------------------------------
# Completed 50 games!
# Successful: 0
# Failed: 50
# Results saved to: games
# Completed configuration: aggressive_vs_balanced
# ================================================================================
#
# Running configuration: conservative_vs_balanced
# Starting 50 games with configuration: conservative_vs_balanced
# Team 1: ['Alice (conservative, risk=0.2)', 'Bob (conservative, risk=0.2)']
# Team 2: ['Charlie (balanced, risk=0.5)', 'David (balanced, risk=0.5)']
# Using 16 parallel workers
# --------------------------------------------------------------------------------
# Game 1/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 2/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 3/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 4/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 5/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 6/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 7/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 8/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 9/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 10/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 11/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 12/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 13/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 14/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 15/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 16/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 17/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 18/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 19/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 20/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 21/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 22/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 23/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 24/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 25/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 26/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 27/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 28/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 29/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 30/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 31/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 32/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 33/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 34/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 35/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 36/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 37/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 38/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 39/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 40/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 41/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 42/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 43/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 44/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 45/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 46/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 47/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 48/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 49/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 50/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# --------------------------------------------------------------------------------
# Completed 50 games!
# Successful: 0
# Failed: 50
# Results saved to: games
# Completed configuration: conservative_vs_balanced
# ================================================================================
#
# Running configuration: opportunistic_vs_aggressive
# Starting 50 games with configuration: opportunistic_vs_aggressive
# Team 1: ['Alice (opportunistic, risk=0.7)', 'Bob (opportunistic, risk=0.7)']
# Team 2: ['Charlie (aggressive, risk=0.8)', 'David (aggressive, risk=0.8)']
# Using 16 parallel workers
# --------------------------------------------------------------------------------
# Game 1/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 2/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 3/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 4/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 5/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 6/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 7/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 8/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 9/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 10/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 11/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 12/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 13/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 14/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 15/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 16/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 17/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 18/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 19/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 20/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 21/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 22/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 23/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 24/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 25/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 26/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 27/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 28/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 29/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 30/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 31/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 32/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 33/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 34/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 35/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 36/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 37/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 38/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 39/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 40/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 41/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 42/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 43/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 44/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 45/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 46/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 47/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 48/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 49/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 50/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# --------------------------------------------------------------------------------
# Completed 50 games!
# Successful: 0
# Failed: 50
# Results saved to: games
# Completed configuration: opportunistic_vs_aggressive
# ================================================================================
#
# Running configuration: mixed_vs_mixed
# Starting 50 games with configuration: mixed_vs_mixed
# Team 1: ['Alice (aggressive, risk=0.8)', 'Bob (conservative, risk=0.2)']
# Team 2: ['Charlie (balanced, risk=0.5)', 'David (opportunistic, risk=0.7)']
# Using 16 parallel workers
# --------------------------------------------------------------------------------
# Game 1/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 2/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 3/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 4/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 5/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 6/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 7/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 8/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 9/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 10/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 11/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 12/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 13/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 14/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 15/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 16/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 17/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 18/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 19/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 20/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 21/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 22/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 23/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 24/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 25/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 26/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 27/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 28/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 29/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 30/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 31/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 32/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 33/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 34/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 35/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 36/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 37/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 38/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 39/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 40/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 41/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 42/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 43/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 44/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 45/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 46/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 47/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 48/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 49/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# Game 50/50: FAILED - EuchreGame.__init__() got an unexpected keyword argument 'enable_logging'
# --------------------------------------------------------------------------------
# Completed 50 games!
# Successful: 0
# Failed: 50
# Results saved to: games
# Completed configuration: mixed_vs_mixed
# ================================================================================
# ✅ All configurations completed!
# 📁 Results saved to: games

# %% [markdown]
# ## Cleanup Old Games

# %%
# Clean up old game files (older than 7 days)
print("🧹 Cleaning up old game files...")
removed_count = runner.cleanup_old_games(7)
print(f"✅ Cleaned up {removed_count} old game files")

# Show current game count
current_count = runner.get_game_count()
print(f"📊 Current game files: {current_count}")
# Out:
# 🧹 Cleaning up old game files...
# ✅ Cleaned up 0 old game files
# 📊 Current game files: 2000
