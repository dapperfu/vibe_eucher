# %% [markdown]
# # Level3 AI Order Up Logic

# %% [markdown]
# This notebook demonstrates how the Level3 AI makes trump calling decisions.

# %% [markdown]
# ## Setup and Imports

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))
print('✅ Imports successful')
