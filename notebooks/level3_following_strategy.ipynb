# %% [markdown]
# # Level3 AI Following Strategies

# %% [markdown]
# This notebook demonstrates how the Level3 AI makes decisions when following.

# %% [markdown]
# ## Setup and Imports

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))
print('✅ Imports successful')
