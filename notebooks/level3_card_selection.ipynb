# %% [markdown]
# # Level3 AI Card Selection Logic

# %% [markdown]
# This notebook demonstrates how the Level3 AI selects cards to play.

# %% [markdown]
# ## Setup and Imports

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))
print('✅ Imports successful')
