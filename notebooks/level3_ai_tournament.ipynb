# %% [markdown]
# # Level3 AI Tournament

# %% [markdown]
# This notebook demonstrates a tournament between different Level3 AI profiles.

# %% [markdown]
# ## Setup and Imports

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))
print('✅ Imports successful')
