# %% [markdown]
# # Interactive Full Game
#
# This notebook allows you to play a full game interactively in Jupyter.
#
# You can:
# - Play as one player in a 4-player game
# - Make all decisions (order up, call trump, play cards)
# - See game progress and final results

# %%
import sys
from pathlib import Path

# Add project root to path
project_root = Path().resolve().parent
sys.path.insert(0, str(project_root))

from eucher.cards import Card, Deck, Suit
from eucher.game import Game
from eucher.rules import RulesEngine
from eucher.players.base import PlayerProfile
from IPython.display import display, HTML, clear_output
import ipywidgets as widgets
from typing import List, Optional

# %%
class InteractivePlayerProfile(PlayerProfile):
    """Player profile for interactive gameplay."""
    
    def __init__(self, player_id: int):
        super().__init__()
        self.player_id = player_id
        self.decisions = []
        
    def decide_order_up(self, player, turned_card, dealer_id, trump_suit):
        """Interactive order up decision."""
        # This will be handled by widgets
        return False
    
    def decide_call_trump(self, player, turned_card, trump_suit, must_choose=False):
        """Interactive trump call decision."""
        return None
    
    def choose_card_to_discard(self, player, turned_card=None, ordered_up_by=None):
        """Interactive discard decision."""
        return player.hand[0]  # Default
    
    def play_card(self, player, led_suit, trump_suit, trick_cards, trick_player_ids):
        """Interactive card play."""
        return player.hand[0]  # Default

# Create game with interactive player
player_config = [
    ("You", "simple"),  # You will control this
    ("AI1", "simple"),
    ("AI2", "simple"),
    ("AI3", "simple"),
]

game = Game(player_config)
display(HTML("<h3>Game Started! You are Player 0.</h3>"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 34
#      26 # Create game with interactive player
#      27 player_config = [
#      28     ("You", "simple"),  # You will control this
#      29     ("AI1", "simple"),
#      30     ("AI2", "simple"),
#      31     ("AI3", "simple"),
#      32 ]
# ---> 34 game = Game(player_config)
#      35 display(HTML("<h3>Game Started! You are Player 0.</h3>"))
#
# File /projects/vibe_eucher/eucher/game.py:117, in Game.__init__(self, player_config, trump_selection_risk, gameplay_risk, seed, trade_in_enabled)
#     115 # Create players with profiles
#     116 for i, (name, profile_type) in enumerate(player_config):
# --> 117     profile = self._create_profile(profile_type, i)
#     118     player = Player(name, i, profile)
#     119     self.players.append(player)
#
# File /projects/vibe_eucher/eucher/game.py:234, in Game._create_profile(self, profile_type, player_id)
#     231     return player
#     232 else:
#     233     # Unknown profile type - check if it's a plugin we haven't loaded yet
# --> 234     raise ValueError(
#     235         f"Unknown profile type: {profile_type}. "
#     236         f"Available plugins: {', '.join(registry.list_plugins())}"
#     237     )
#
# ValueError: Unknown profile type: simple. Available plugins: ai, heuristic, heuristic2, ml_sklearn, ml_rl, ml_gan, ml_pytorch, pytorch_ai, pytorch_strategic, random, euchre_zero, perceiver_muzero, perceiver_muzero_1, perceiver_muzero_16, perceiver_muzero_64, perceiver_muzero_128

# %% [markdown]
# ## Game Controls

# %%
# Game state display
def display_game_state():
    """Display current game state."""
    html = f"""
    <div style="border: 2px solid #333; padding: 10px; margin: 10px;">
        <h3>Game State</h3>
        <p><strong>Scores:</strong> Team 0 = {game.scores[0]}, Team 1 = {game.scores[1]}</p>
        <p><strong>Current Hand:</strong> {len([h for h in game.hands_played if h]) if hasattr(game, 'hands_played') else 'N/A'}</p>
        <p><strong>Dealer:</strong> Player {game.dealer_id}</p>
    </div>
    """
    display(HTML(html))

display_game_state()

# Play next hand button
play_hand_button = widgets.Button(description="Play Next Hand", button_style='success')
hand_output = widgets.Output()

def on_play_hand(b):
    with hand_output:
        clear_output()
        display(HTML("<p>Playing hand...</p>"))
        continue_game = game.play_hand()
        clear_output()
        display_game_state()
        if continue_game:
            winner = game.get_winner()
            if winner is not None:
                display(HTML(f"<h2>Game Over! Team {winner} wins!</h2>"))
            else:
                display(HTML("<p>Hand complete. Click 'Play Next Hand' to continue.</p>"))
        else:
            display(HTML("<p>Game ended.</p>"))

play_hand_button.on_click(on_play_hand)
display(play_hand_button)
display(hand_output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 14
#       4     html = f"""
#       5     <div style="border: 2px solid #333; padding: 10px; margin: 10px;">
#       6         <h3>Game State</h3>
#    (...)     10     </div>
#      11     """
#      12     display(HTML(html))
# ---> 14 display_game_state()
#      16 # Play next hand button
#      17 play_hand_button = widgets.Button(description="Play Next Hand", button_style='success')
#
# Cell In[3], line 7, in display_game_state()
#       2 def display_game_state():
#       3     """Display current game state."""
#       4     html = f"""
#       5     <div style="border: 2px solid #333; padding: 10px; margin: 10px;">
#       6         <h3>Game State</h3>
# ----> 7         <p><strong>Scores:</strong> Team 0 = {game.scores[0]}, Team 1 = {game.scores[1]}</p>
#       8         <p><strong>Current Hand:</strong> {len([h for h in game.hands_played if h]) if hasattr(game, 'hands_played') else 'N/A'}</p>
#       9         <p><strong>Dealer:</strong> Player {game.dealer_id}</p>
#      10     </div>
#      11     """
#      12     display(HTML(html))
#
# NameError: name 'game' is not defined
