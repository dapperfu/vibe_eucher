# %% [markdown]
# # Euchre OOP Structure Demonstration
#
# This notebook demonstrates the enhanced Object-Oriented Programming structure of the Euchre game.

# %%
# Setup: Add the project root to Python path
import sys
from pathlib import Path

# Add the parent directory to the path so we can import euchre
sys.path.insert(0, str(Path.cwd().parent))

print("✅ Setup complete!")
# Out:
# ✅ Setup complete!

# %% [markdown]
# ## Card Class Demonstration
#
# The enhanced Card class provides properties and methods that encapsulate card-specific logic.

# %%
# Import Card class
from euchre.models import Card, Suit, Rank

# Create some cards
ace_hearts = Card(Rank.ACE, Suit.HEARTS)
print(f"Created: {ace_hearts}")
# Out:
# Created: Ace of Hearts

# %% [markdown]
# ## Deck Class Demonstration
#
# The enhanced Deck class provides comprehensive deck management operations.

# %%
# Import Deck class
from euchre.core import Deck

# Create a deck
deck = Deck()
print(f"Deck size: {deck.size}")
# Out:
# Deck size: 24

# %% [markdown]
# ## Player Class Demonstration
#
# The enhanced Player class provides team management and hand evaluation.

# %%
# Import Player class
from euchre.models import Player, PlayerType

# Create a player
alice = Player("Alice", PlayerType.AI)
print(f"Created: {alice.name}")
# Out:
# Created: Alice
