# %% [markdown]
# # AI Profiles and Strategies
#
# This notebook demonstrates the AI player system and different strategies.

# %%
# Setup and imports
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

from euchre.ai.ai_factory import AIFactory

print("✅ AI profiles test setup complete!")
# Out:
# ✅ AI profiles test setup complete!

# %% [markdown]
# ## AI Factory Pattern
#
# The AI Factory provides a clean way to create different types of AI players.

# %%
# Create AI factory
ai_factory = AIFactory()
print(f"Available profiles: {ai_factory.get_available_profiles()}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Create AI factory
#       2 ai_factory = AIFactory()
# ----> 3 print(f"Available profiles: {ai_factory.get_available_profiles()}")
#
# AttributeError: 'AIFactory' object has no attribute 'get_available_profiles'

# %% [markdown]
# ## Create AI Players
#
# Create different AI players with various strategies.

# %%
# Create AI players
aggressive_alice = ai_factory.create_ai_player("Aggressive_Alice", "aggressive")
conservative_bob = ai_factory.create_ai_player("Conservative_Bob", "conservative")

print(f"Created: {aggressive_alice.name} ({aggressive_alice.ai_profile})")
print(f"Created: {conservative_bob.name} ({conservative_bob.ai_profile})")

# %% [markdown]
# ## Strategy Analysis
#
# Analyze how different AI strategies approach the game.

# %%
# Analyze strategies
print("Aggressive AI:")
print("- Leads with trump cards and high cards")
print("- Calls trump more frequently")
print("
Conservative AI:")
print("- Leads with low cards and non-trump")
print("- Only calls trump with very strong hands")
